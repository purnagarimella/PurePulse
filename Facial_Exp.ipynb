# %% [markdown]
# <a href="https://colab.research.google.com/github/purnagarimella/PurePulse/blob/main/Facial_Exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Apr  8 03:14:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.1/994.1 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.9/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="thg2q1G5kjsElNwqf77b")
project = rf.workspace("own-wokrspace").project("facial-data")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Facial-Data-2 in yolov11:: 100%|██████████| 2417/2417 [00:00<00:00, 8515.78it/s]

# %%
dataset.location
# Out:
# '/content/Facial-Data-2'

# %%
# !yolo task=detect mode=train epochs=300 data={dataset.location}/data.yaml model="yolo11n.pt" imgsz=640
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image("/content/runs/detect/train/confusion_matrix.png",width=1000)

# %%
Image("/content/runs/detect/train/results.png",width=1000)

# %%
Image("/content/runs/detect/train/labels.jpg",width=1000)

# %%
Image("/content/runs/detect/train/train_batch0.jpg",width=1000)

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/Facial-Data-2/valid/labels.cache... 239 images, 0 backgrounds, 0 corrupt: 100% 239/239 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 15/15 [00:03<00:00,  3.90it/s]
#                    all        239        921      0.463      0.745      0.591      0.495
#                  angry         84        176      0.366      0.699      0.478      0.349
#                disgust         40         40       0.55        0.8      0.795      0.783
#                   fear         53        143      0.395      0.685      0.542      0.405
#                  happy         68        202      0.602      0.703       0.77      0.558
#                neutral         56        167      0.285      0.862      0.384      0.278
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.104 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/121 /content/Facial-Data-2/test/images/1-4-_jpg.rf.c8154a5284ef57042771cec83ce875a9.jpg: 640x640 1 angry, 11.1ms
# image 2/121 /content/Facial-Data-2/test/images/1-5-_jpg.rf.c5c9ca642ec9901ff40310889dced115.jpg: 640x640 1 angry, 8.8ms
# image 3/121 /content/Facial-Data-2/test/images/1-7-_jpg.rf.dff0944e57af5f37459f5a07129d3c54.jpg: 640x640 (no detections), 8.2ms
# image 4/121 /content/Facial-Data-2/test/images/1-8-_jpg.rf.8eafbf8230cf126a4910602fde492b7e.jpg: 640x640 (no detections), 8.1ms
# image 5/121 /content/Facial-Data-2/test/images/11_jpg.rf.af6bad80ed38977dc1420b6e776d5fc2.jpg: 640x640 4 angrys, 4 fears, 2 happys, 11 neutrals, 1 sad, 7.9ms
# image 6/121 /content/Facial-Data-2/test/images/16_jpg.rf.4359a6fc187b2d81a903197a8d48a762.jpg: 640x640 5 angrys, 1 fear, 3 happys, 9 neutrals, 7.9ms
# ...
